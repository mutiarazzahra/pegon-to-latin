# %%
import nltk
import pandas as pd
import string, re
import numpy as np
from collections import Counter

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
latin_df = pd.read_excel('latin.xlsx')
latin_df.head()
# Out:
#              token             file
# 0            'abdi  Tarikhul Auliya
# 1  'abdil-muṭṭalib  Tarikhul Auliya
# 2        'abdillāh  Tarikhul Auliya
# 3     'abdul-jalīl  Tarikhul Auliya
# 4     'abdul-majīd  Tarikhul Auliya

# %%
pegon_df = pd.read_excel('pegon.xlsx')
pegon_df.head()
# Out:
#   token             file
# 0     ﷽  Tarikhul Auliya
# 1     ١  Tarikhul Auliya
# 2     ١    Ilmu Tasawwuf
# 3    ١٠  Tarikhul Auliya
# 4    ١١  Tarikhul Auliya

# %% [markdown]
# # Compare Character on Manuscript to Pegon-Latin Character Rules

# %%
def get_unique_characters_and_unicode_df(df, token_col='token'):
    # Concatenate all tokens into a single string
    all_tokens = ''.join(df[token_col])

    # Use Counter to count the frequency of each character
    character_counts = Counter(all_tokens)

    # Create a list of dictionaries with character, frequency, and Unicode value
    unicode_data = [{'char': char, 'frequency': freq, 'utf16': f'{ord(char):04X}'}
                    for char, freq in character_counts.items()]

    # Create a DataFrame from the list of dictionaries
    unicode_df = pd.DataFrame(unicode_data)

    return unicode_df

# %%
'''
Extract unique characters from Pegon tokens and its utf16
'''

pegon_unicode_df = get_unique_characters_and_unicode_df(pegon_df)
pegon_unicode_df
# Out:
#    char  frequency utf16
# 0     ﷽          1  FDFD
# 1     ١         59  0661
# 2     ٠          9  0660
# 3     ٢        137  0662
# 4     ٣         12  0663
# ..  ...        ...   ...
# 81    i          1  0069
# 82    ک          8  06A9
# 83    ࢌ          2  088C
# 84    ‌          5  200C
# 85    گ          2  06AF
#
# [86 rows x 3 columns]

# %%
'''
Extract unique characters from Latin tokens and its utf16
'''

latin_unicode_df = get_unique_characters_and_unicode_df(latin_df)
latin_unicode_df
# Out:
#    char  frequency utf16
# 0     '        357  0027
# 1     a       8263  0061
# 2     b       1095  0062
# 3     d        960  0064
# 4     i       2918  0069
# 5     l       1851  006C
# 6     -        228  002D
# 7     m       1708  006D
# 8     u       2898  0075
# 9     ṭ         71  1E6D
# 10    ā        651  0101
# 11    h       1217  0068
# 12    j        464  006A
# 13    ī        224  012B
# 14    k       1693  006B
# 15    q        215  0071
# 16    r       1935  0072
# 17    n       4043  006E
# 18    w        611  0077
# 19    y        655  0079
# 20    s       1430  0073
# 21    t       1601  0074
# 22    ū        153  016B
# 23    ṣ        170  1E63
# 24    f        431  0066
# 25    e       1265  0065
# 26    ḍ        130  1E0D
# 27    o        682  006F
# 28    ẑ         71  1E91
# 29    ẓ         25  1E93
# 30    2        125  0032
# 31    ṫ          1  1E6B
# 32    1         61  0031
# 33    0         13  0030
# 34    3         13  0033
# 35    7         14  0037
# 36    4         15  0034
# 37    5         20  0035
# 38    8         15  0038
# 39    6         13  0036
# 40    9         17  0039
# 41    z         63  007A
# 42    ě        255  011B
# 43    c        195  0063
# 44    g       1393  0067
# 45    ê        900  00EA
# 46    ḥ        138  1E25
# 47    p        643  0070
# 48    ṅ        338  1E45
# 49    ṯ         53  1E6F
# 50    ẖ         22  1E96
# 51    ḵ         10  1E35
# 52    ṡ         36  1E61
# 53    ś         18  015B
# 54    ñ         24  00F1
# 55    ḏ          1  1E0F
# 56    ḋ          5  1E0B
# 57    ⅲ          1  2172
# 58    ō          1  014D
# 59    ž          1  017E

# %%
pegon_rules_unicodes = [
    "0621", "0622", "0623", "0624", "0625", "0626", "0627", "0628", "0629",
    "062A", "062B", "062C", "062D", "062E", "062F", "0630", "0631", "0632",
    "0633", "0634", "0635", "0636", "0637", "0638", "0639", "063A", "063C",
    "0641", "0642", "0643", "0644", "0645", "0646", "0647", "0648", "0649",
    "064A", "064B", "064C", "064D", "064E", "064F", "0650", "0651", "0652",
    "0653", "0656", "0657", "0660", "0661", "0662", "0663", "0664", "0665",
    "0666", "0667", "0668", "0669", "0670", "067E", "0684", "0686", "068A",
    "06A0", "06A4", "06AC", "06AD", "06AE", "06BD", "06CB", "06D0", "06D1",
    "06E1", "0762", "0763", "088B", "088C", "088D", "08E4", "08AE", "08B4",
    "10EC2", "10EC3", "10EC4"
]

# %%
latin_rules_unicodes = [
    "0027", "0030", "0031", "0032", "0033", "0034", "0035", "0036", "0037",
    "0038", "0039", "0060", "0061", "0062", "0063", "0064", "0065", "0066",
    "0067", "0068", "0069", "006A", "006B", "006C", "006D", "006E", "006F",
    "0070", "0070", "0071", "0072", "0073", "0074", "0075", "0076", "0077",
    "0079", "007A", "00F1", "0101", "011B", "0121", "012B", "015B", "016B",
    "1E0B", "1E0D", "1E0F", "1E35", "1E45", "1E63", "1E6B", "1E6D", "1E6F",
    "1E95", "1E96"
]

# %%
'''
Find character in Pegon and Latin Token which not included on rules
'''

non_pegon_unicode = pegon_unicode_df[~pegon_unicode_df['utf16'].isin(pegon_rules_unicodes)]
non_latin_unicode = latin_unicode_df[~latin_unicode_df['utf16'].isin(latin_rules_unicodes)]

# %%
non_pegon_unicode
# Out:
#    char  frequency utf16
# 0     ﷽          1  FDFD
# 12    ۳          1  06F3
# 13    Ⅲ          1  2162
# 14    K          1  004B
# 15    T          1  0054
# 16    N          1  004E
# 17    R          1  0052
# 18    I          1  0049
# 19    S          1  0053
# 51    ی         19  06CC
# 56    ۲         19  06F2
# 57    ݒ          9  0752
# 65    ݘ         11  0758
# 71    ݤ        105  0764
# 74    ؿ          1  063F
# 77    ے          9  06D2
# 81    i          1  0069
# 82    ک          8  06A9
# 84    ‌          5  200C
# 85    گ          2  06AF

# %%
non_latin_unicode
# Out:
#    char  frequency utf16
# 6     -        228  002D
# 28    ẑ         71  1E91
# 29    ẓ         25  1E93
# 45    ê        900  00EA
# 46    ḥ        138  1E25
# 52    ṡ         36  1E61
# 57    ⅲ          1  2172
# 58    ō          1  014D
# 59    ž          1  017E

# %% [markdown]
# # Analyze Character

# %%
def char_stats(series):
    # Concatenate strings
    concatenated = ''.join(series)

    # Total character count
    char_count = len(concatenated)

    # Unique characters set
    unique_chars = set(concatenated)

    # Count of unique characters
    unique_char_count = len(unique_chars)

    # Convert set to list
    unique_char_list = list(unique_chars)

    return char_count, unique_char_count, unique_char_list

# %%
def calculate_char_stats(df, group_by_col='language', token_col='token'):
    # Group by and calculate stats
    grouped_df = df.groupby(group_by_col)[token_col].agg(char_stats).reset_index()

    # Split stats into columns
    grouped_df[['char count', 'unique char count', 'unique char list']] = pd.DataFrame(grouped_df[token_col].tolist(), index=grouped_df.index)

    # Drop token column
    grouped_df.drop(columns=token_col, inplace=True)

    return grouped_df

# %%
def calculate_overall_stats(df, group_by_col='language', token_col='token'):
    # Overall stats calculation
    overall_stats = char_stats(df[token_col])

    # Overall stats DataFrame
    overall_df = pd.DataFrame([['All', *overall_stats]], columns=[group_by_col, 'char count', 'unique char count', 'unique char list'])

    return overall_df

# %%
def find_char_stats(df, token_col='token', group_by_col='language'):
    # Group-wise and overall stats combination
    char_df = calculate_char_stats(df, group_by_col, token_col)
    overall_df = calculate_overall_stats(df, group_by_col, token_col)
    combined_df = pd.concat([char_df, overall_df], ignore_index=True)

    return combined_df

# %% [markdown]
# ## Analyze Character per Language

# %%
'''
Add language column to analyze per language
'''

latin_df['language'] = np.where(latin_df['file'].isin(['Tarikhul Auliya', 'Mitro Sejati']), 'Jawa', 'sunda')
pegon_df['language'] = np.where(pegon_df['file'].isin(['Tarikhul Auliya', 'Mitro Sejati']), 'Jawa', 'sunda')

# %%
'''
Count Latin Characters per Language
'''

latin_char_df = find_char_stats(latin_df)
latin_char_df
# Out:
#   language  char count  unique char count  \
# 0     Jawa       15058                 57
# 1    sunda       27361                 53
# 2      All       42419                 60
#
#                                     unique char list
# 0  [ḋ, ś, ẑ, ḍ, ṅ, n, t, ī, s, ḥ, p, o, l, 1, ṣ, ...
# 1  [ś, ḋ, ẑ, ḍ, n, t, ī, s, ḥ, p, o, l, 1, ṣ, i, ...
# 2  [ś, ḋ, ẑ, ḍ, ṅ, n, t, ī, s, ḥ, p, o, l, 1, ṣ, ...

# %%
'''
Count Pegon Characters per Language
'''

pegon_char_df = find_char_stats(pegon_df)
pegon_char_df
# Out:
#   language  char count  unique char count  \
# 0     Jawa       24461                 78
# 1    sunda       39593                 69
# 2      All       64054                 86
#
#                                     unique char list
# 0  [ى, ل, ٠, ِ, آ, ج, ے, ڤ, ث, س, ّ, ۳, ه, ط, ب, ...
# 1  [ش, ح, ‌, ى, ٦, م, ٩, أ, ل, ٰ, پ, ظ, ٤, َ, ِ, ...
# 2  [ى, ل, ٠, ِ, آ, ۲, ج, ݤ, ے, ڤ, ؿ, ث, س, إ, ّ, ...

# %% [markdown]
# ## Analyze Character per File

# %%
'''
Count Latin Characters per Manuscripts
'''

latin_char_df = find_char_stats(latin_df, group_by_col='file')
latin_char_df
# Out:
#               file  char count  unique char count  \
# 0    Ilmu Tasawwuf        5037                 46
# 1     Mitro Sejati        3970                 37
# 2   Qisasul Anbiya       22324                 51
# 3  Tarikhul Auliya       11088                 57
# 4              All       42419                 60
#
#                                     unique char list
# 0  [ẑ, ḍ, n, t, ī, s, ḥ, p, o, l, 1, ṣ, i, ṭ, z, ...
# 1  [ẑ, ḍ, t, n, ī, ḥ, s, o, l, ṣ, i, ṭ, z, ṡ, ū, ...
# 2  [ś, ḋ, ẑ, ḍ, n, t, ī, s, ḥ, p, o, l, 1, ṣ, i, ...
# 3  [ḋ, ś, ẑ, ḍ, ṅ, n, t, ī, s, ḥ, p, o, l, 1, ṣ, ...
# 4  [ś, ḋ, ẑ, ḍ, ṅ, n, t, ī, s, ḥ, p, o, l, 1, ṣ, ...

# %%
'''
Count Latin Characters per Manuscripts
'''

pegon_char_df = find_char_stats(pegon_df, group_by_col='file')
pegon_char_df
# Out:
#               file  char count  unique char count  \
# 0    Ilmu Tasawwuf        6817                 62
# 1     Mitro Sejati        6085                 49
# 2   Qisasul Anbiya       32776                 58
# 3  Tarikhul Auliya       18376                 76
# 4              All       64054                 86
#
#                                     unique char list
# 0  [ش, ح, ى, ٦, م, ٩, ٰ, ل, پ, ظ, أ, ٤, َ, ِ, ه, ...
# 1  [ش, ح, ى, م, ٰ, ظ, أ, ل, پ, َ, ِ, ه, ط, ع, ب, ...
# 2  [ش, ح, ‌, ى, م, أ, ٰ, ظ, ل, پ, َ, ِ, ه, ع, ط, ...
# 3  [ش, ح, ى, م, ٦, ٩, ۳, ٰ, K, ل, أ, ظ, ٠, ٤, َ, ...
# 4  [ى, ل, ٠, ِ, آ, ۲, ج, ݤ, ے, ڤ, ؿ, ث, س, إ, ّ, ...

# %% [markdown]
# ## Analyze Character on Final Dataset

# %%
df = pd.read_csv('Jawa-Sunda.csv')
df.head()
# Out:
#   language             pegon      latin
# 0     Jawa             تاريخ      tariḵ
# 1     Jawa              والى       wali
# 2     Jawa               سڠا        sṅa
# 3     Jawa      نࣤرَاڠَاكࣤنْ  něraṅakěn
# 4     Jawa  بَبَادْاِيْفُونْ  babadipun

# %%
'''
Count Latin Characters per Language
'''

latin_char_df = find_char_stats(df, token_col='latin')
latin_char_df
# Out:
#   language  char count  unique char count  \
# 0     Jawa       15147                 54
# 1    Sunda       26693                 42
# 2      All       41840                 54
#
#                                     unique char list
# 0  [ḋ, ś, ḍ, ṅ, t, n, ī, s, o, l, 1, ṣ, i, ṭ, z, ...
# 1  [ḋ, ś, ṅ, t, n, ī, s, p, o, l, ṣ, i, z, ṯ, `, ...
# 2  [ḋ, ś, ḍ, ṅ, t, n, ī, s, o, l, 1, ṣ, i, ṭ, z, ...

# %%
'''
Count Pegon Characters per Language
'''

pegon_char_df = find_char_stats(df, token_col='pegon')
pegon_char_df
# Out:
#   language  char count  unique char count  \
# 0     Jawa       23177                 65
# 1    Sunda       37423                 54
# 2      All       60600                 68
#
#                                     unique char list
# 0  [ش, ح, ى, م, ظ, ٰ, أ, ل, ٦, ٩, ٠, ٤, َ, ِ, ه, ...
# 1  [ش, ح, ى, م, ٰ, أ, ظ, ل, ِ, َ, ه, ع, ط, ب, ق, ...
# 2  [ش, ح, ى, م, ظ, ٰ, أ, ل, ٦, ٩, ٠, ٤, َ, ِ, ه, ...

# %% [markdown]
# # Save Final dataset

# %%
'''
Penyimpanan Dataset bahasa Jawa
'''

df_jawa = df[df['language'] == 'Jawa'][['pegon', 'latin']]
df_jawa.to_csv('Jawa.csv', index=False)
df_jawa.shape
# Out:
# (2483, 2)

# %%
'''
Penyimpanan Dataset bahasa Sunda
'''

df_sunda = df[df['language'] == 'Sunda'][['pegon', 'latin']]
df_sunda[['pegon', 'latin']].to_csv('Sunda.csv', index=False)
df_sunda.shape
# Out:
# (4103, 2)

# %%
'''
Penyimpanan Dataset semua bahasa
'''

df_all = df[['pegon', 'latin']]
df_all.to_csv('All.csv', index=False)
df_all.shape
# Out:
# (6586, 2)

# %% [markdown]
# ## Analyze Character on Each Final Dataset

# %% [markdown]
# ### All Dataset

# %%
'''
Frequency Each Character in pegon
'''

freq_df = get_unique_characters_and_unicode_df(df_all, 'pegon')
freq_df.sort_values('frequency').head(15)
# Out:
#    char  frequency utf16
# 66    ﻿          1  FEFF
# 63    -          1  002D
# 25    ࢌ          2  088C
# 43    ٖ          5  0656
# 57    ٠          9  0660
# 60    ٦         11  0666
# 56    ٧         12  0667
# 55    ٣         12  0663
# 59    ٤         13  0664
# 61    ٨         13  0668
# 62    ٩         16  0669
# 58    ٥         17  0665
# 52    ڤ         17  06A4
# 32    ظ         23  0638
# 36    ث         40  062B

# %%
freq_df.sort_values('frequency').tail(15)
# Out:
#    char  frequency utf16
# 8     س       1375  0633
# 0     ت       1501  062A
# 13    ك       1624  0643
# 23    م       1648  0645
# 11    ࣤ       1691  08E4
# 6     ل       1741  0644
# 2     ر       1935  0631
# 3     ي       2402  064A
# 19    ُ       2649  064F
# 5     و       2845  0648
# 10    ن       3022  0646
# 17    ِ       3032  0650
# 1     ا       4784  0627
# 14    ْ       9171  0652
# 12    َ      10256  064E

# %%
'''
Frequency Each Character in pegon
'''

freq_df = get_unique_characters_and_unicode_df(df_all, 'latin')
freq_df.sort_values('frequency').head(15)
# Out:
#    char  frequency utf16
# 21    ṭ          2  1E6D
# 39    ī          5  012B
# 48    0          9  0030
# 51    6         11  0036
# 47    7         12  0037
# 46    3         12  0033
# 50    4         13  0034
# 52    8         13  0038
# 53    9         16  0039
# 49    5         17  0035
# 31    ẕ         24  1E95
# 34    ṫ         43  1E6B
# 33    ḏ         48  1E0F
# 40    ġ         51  0121
# 41    z         55  007A

# %%
freq_df.sort_values('frequency').tail(15)
# Out:
#    char  frequency utf16
# 17    h        953  0068
# 14    p        981  0070
# 12    b       1085  0062
# 8     ṅ       1260  1E45
# 7     s       1389  0073
# 11    k       1630  006B
# 0     t       1672  0074
# 19    m       1678  006D
# 10    ě       1692  011B
# 6     l       1714  006C
# 2     r       1967  0072
# 15    u       2730  0075
# 3     i       3166  0069
# 9     n       3252  006E
# 1     a       9210  0061

# %% [markdown]
# ### Sunda Dataset

# %%
'''
Frequency Each Character in pegon
'''

freq_df = get_unique_characters_and_unicode_df(df_sunda, 'pegon')
freq_df.sort_values('frequency')
# Out:
#    char  frequency utf16
# 51    ﻿          1  FEFF
# 52    ٖ          1  0656
# 48    ظ         19  0638
# 44    ث         32  062B
# 50    ز         36  0632
# 27    غ         36  063A
# 47    ض         38  0636
# 20    ٰ         41  0670
# 35    ٌ         41  064C
# 33    ط         42  0637
# 49    ؤ         48  0624
# 37    آ         49  0622
# 34    ش         49  0634
# 36    ٢         51  0662
# 38    ء         52  0621
# 25    ذ         53  0630
# 28    ٍ         54  064D
# 42    خ         67  062E
# 43    ً         68  064B
# 26    ى         85  0649
# 41    إ         86  0625
# 13    ص         87  0635
# 53    ؼ        104  063C
# 32    ة        106  0629
# 39    ۑ        118  06D1
# 40    ئ        120  0626
# 23    ح        126  062D
# 46    چ        137  0686
# 19    ق        180  0642
# 30    ڮ        201  06AE
# 22    ع        258  0639
# 15    ّ        281  0651
# 29    ج        298  062C
# 45    أ        421  0623
# 24    د        572  062F
# 21    ه        661  0647
# 17    ف        666  0641
# 4     ب        708  0628
# 31    ڠ        751  06A0
# 18    س        849  0633
# 3     ࣤ        917  08E4
# 9     ت       1003  062A
# 7     م       1003  0645
# 11    ك       1067  0643
# 8     ر       1148  0631
# 10    ل       1154  0644
# 2     ي       1485  064A
# 14    و       1619  0648
# 16    ُ       1696  064F
# 1     ِ       1897  0650
# 12    ن       1981  0646
# 0     ا       2591  0627
# 6     ْ       5541  0652
# 5     َ       6728  064E

# %%
'''
Frequency Each Character in pegon
'''

freq_df = get_unique_characters_and_unicode_df(df_sunda, 'latin')
freq_df.sort_values('frequency')
# Out:
#    char  frequency utf16
# 41    ī          1  012B
# 39    ẕ         20  1E95
# 36    ṫ         35  1E6B
# 25    ġ         36  0121
# 40    z         38  007A
# 38    ḏ         39  1E0F
# 30    ṯ         43  1E6F
# 32    2         51  0032
# 24    ḋ         53  1E0B
# 31    ś         56  015B
# 35    ḵ         69  1E35
# 33    `         77  0060
# 12    ṣ         97  1E63
# 19    ā         97  0101
# 34    ñ        117  00F1
# 22    ẖ        127  1E96
# 37    c        137  0063
# 17    -        175  002D
# 18    q        183  0071
# 21    '        258  0027
# 26    j        300  006A
# 27    g        305  0067
# 1     y        312  0079
# 8     e        332  0065
# 29    o        381  006F
# 13    w        431  0077
# 23    d        581  0064
# 20    h        649  0068
# 15    p        668  0070
# 3     b        731  0062
# 28    ṅ        751  1E45
# 16    s        858  0073
# 2     ě        918  011B
# 5     m       1025  006D
# 10    k       1073  006B
# 7     t       1116  0074
# 9     l       1137  006C
# 6     r       1174  0072
# 14    u       1773  0075
# 0     i       2004  0069
# 11    n       2189  006E
# 4     a       6276  0061

# %% [markdown]
# ### Jawa Dataset

# %%
'''
Frequency Each Character in pegon
'''

freq_df = get_unique_characters_and_unicode_df(df_jawa, 'pegon')
freq_df.sort_values('frequency').head(15)
# Out:
#    char  frequency utf16
# 63    -          1  002D
# 34    ٌ          2  064C
# 25    ࢌ          2  088C
# 50    آ          2  0622
# 43    ٖ          4  0656
# 32    ظ          4  0638
# 42    ً          6  064B
# 36    ث          8  062B
# 39    ٍ          8  064D
# 57    ٠          9  0660
# 35    ض          9  0636
# 60    ٦         11  0666
# 38    ذ         11  0630
# 56    ٧         12  0667
# 55    ٣         12  0663

# %%
freq_df.sort_values('frequency').tail(15)
# Out:
#    char  frequency utf16
# 7     ى        510  0649
# 8     س        526  0633
# 13    ك        557  0643
# 6     ل        587  0644
# 23    م        645  0645
# 11    ࣤ        774  08E4
# 2     ر        787  0631
# 3     ي        917  064A
# 19    ُ        953  064F
# 10    ن       1041  0646
# 17    ِ       1135  0650
# 5     و       1226  0648
# 1     ا       2193  0627
# 12    َ       3528  064E
# 14    ْ       3630  0652

# %%
'''
Frequency Each Character in pegon
'''

freq_df = get_unique_characters_and_unicode_df(df_jawa, 'latin')
freq_df
# Out:
#    char  frequency utf16
# 0     t        556  0074
# 1     a       2934  0061
# 2     r        793  0072
# 3     i       1162  0069
# 4     ḵ         15  1E35
# 5     w        239  0077
# 6     l        577  006C
# 7     s        531  0073
# 8     ṅ        509  1E45
# 9     n       1063  006E
# 10    ě        774  011B
# 11    k        557  006B
# 12    b        354  0062
# 13    d        343  0064
# 14    p        313  0070
# 15    u        957  0075
# 16    2        109  0032
# 17    h        304  0068
# 18    j        169  006A
# 19    m        653  006D
# 20    c         76  0063
# 21    ṭ          2  1E6D
# 22    ḍ        108  1E0D
# 23    o        231  006F
# 24    e        458  0065
# 25    ṯ         92  1E6F
# 26    '         83  0027
# 27    q         50  0071
# 28    ẖ         66  1E96
# 29    -         66  002D
# 30    f        134  0066
# 31    ẕ          4  1E95
# 32    y        127  0079
# 33    ḏ          9  1E0F
# 34    ṫ          8  1E6B
# 35    `        115  0060
# 36    ḋ         12  1E0B
# 37    ṣ         72  1E63
# 38    ā         27  0101
# 39    ī          4  012B
# 40    ġ         15  0121
# 41    z         17  007A
# 42    ś         27  015B
# 43    g        242  0067
# 44    ñ         29  00F1
# 45    1         58  0031
# 46    3         12  0033
# 47    7         12  0037
# 48    0          9  0030
# 49    5         17  0035
# 50    4         13  0034
# 51    6         11  0036
# 52    8         13  0038
# 53    9         16  0039
